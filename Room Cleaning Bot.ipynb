# %%
print("..................................")
print(".   *    . ****    .  *****      .")
print(".  * *   . *   *   .  *          .")
print(". *****  . *****   .  *          .")
print(".*     * . *   *   .  *          .")
print(".        . ****    .  *****      .")
print(".................................")

cost = 0
current_room = input("what is your current room?(A,B,C)")

status = input("Is your room is clean(1) or dirty(0) press (0/1)")
if current_room == 'A':

    if status == '0':
        print("your room is dirty")
        print("your room is  being clean")
        cost = cost + 1
        print("\n****moving towards goal*****\n")
        goal = input("what is your goal room")
        cost = cost + 1
        if goal == 'A':
            print("room A is cleaned already")
        elif goal == 'B':
            print("\n****moving right****\n")
            print("entered in Room B  ")
            status = input("Is your room is clean(1) or dirty(0) press (0/1)")
            if status == '0':
                print("Room B is dirty")
                print("cleaning the room ")
                print("Room is cleaned")
                cost = cost + 1
                print("entered in Room C  ")
                print("\n****moving right****\n")
                cost = cost + 1
                status = input("Is this room is clean(1) or dirty(0) press (0/1)")
                if status == '0':
                    print("Room C is being clean")
                    print("Room C is clean")
                    cost = cost + 1
                else:
                    print("entered in Room C  ")
                    print("Room C is clean")
            else:
                print("Room B is clean")
                print("\n****moving right****\n")
                cost = cost + 1
                print("entered in Room C  ")
                status = input("Is this room is clean(1) or dirty(0) press (0/1)")

                if status == '0':

                    print("Room C is being clean")
                    print("Room C is clean")
                    cost = cost + 1
                else:
                    print("entered in Room C  ")
                    print("Room C is clean")



        else:
            print("\n****moving right****\n")
            print("entered in Room B  ")
            cost = cost + 1
            status = input("Is your room is clean(1) or dirty(0) press (0/1)")
            if status == '0':
                print("Room B is dirty")
                print("cleaning the room ")
                print("Room is cleaned")
                cost = cost + 1
                print("\n****moving right****\n")
                cost = cost + 1
                status = input("Is this room is clean(1) or dirty(0) press (0/1)")
                if status == '0':
                    print("entered in Room C  ")
                    print("Room C is being clean")
                    print("Room C is clean")
                    cost = cost + 1
                else:
                    print("entered in Room C  ")
                    print("Room C is clean")
            else:
                print("Room B is clean")
                print("\n****moving right****\n")
                cost = cost + 1
                status = input("Is this room is clean(1) or dirty(0) press (0/1)")
                if status == '0':
                    print("entered in Room C  ")
                    print("Room C is being clean")
                    print("Room C is clean")
                    cost = cost + 1
                else:
                    print("entered in Room C  ")
                    print("Room C is clean")



    elif status == '1':
        print("your room is clean")
        print("\n****moving towards goal*****\n")
        goal = input("what is your goal room")
        if goal == 'A':
            print("room A is cleaned already")
        elif goal == 'B':
            print("\n****moving right****\n")
            print("entered in Room B  ")
            cost = cost + 1
            status = input("Is your room is clean(1) or dirty(0) press (0/1)")
            if status == '0':
                print("Room B is dirty")
                print("cleaning the room ")
                print("Room is cleaned")
                cost = cost + 1
                print("\n****moving right****\n")
                cost = cost + 1
                status = input("Is this room is clean(1) or dirty(0) press (0/1)")
                if status == '0':
                    print("entered in Room C  ")
                    print("Room C is being clean")
                    print("Room C is clean")
                    cost = cost + 1
                else:
                    print("entered in Room C  ")
                    print("Room C is clean")
            else:
                print("Room B is clean")
                print("\n****moving right****\n")
                cost = cost + 1
                status = input("Is this room is clean(1) or dirty(0) press (0/1)")
                if status == '0':
                    print("entered in Room C  ")
                    print("Room C is being clean")
                    print("Room C is clean")
                    cost = cost + 1
                else:
                    print("entered in Room C  ")
                    print("Room C is clean")
        else:
            print("\n****moving right****\n")
            print("entered in Room B  ")
            cost = cost + 1
            status = input("Is your room is clean(1) or dirty(0) press (0/1)")
            if status == '0':
                print("Room B is dirty")
                print("cleaning the room ")
                print("Room is cleaned")
                cost = cost + 1
                print("\n****moving right****\n")
                cost = cost + 1
                status = input("Is this room is clean(1) or dirty(0) press (0/1)")
                if status == '0':
                    print("entered in Room C  ")
                    print("Room C is being clean")
                    print("Room C is clean")
                    cost = cost + 1
                else:
                    print("entered in Room C  ")
                    print("Room C is clean")
            else:
                print("Room B is clean")
                print("\n****moving right****\n")
                cost = cost + 1
                status = input("Is this room is clean(1) or dirty(0) press (0/1)")
                if status == '0':
                    print("entered in Room C  ")
                    print("Room C is being clean")
                    print("Room C is clean")
                    cost = cost + 1
                else:
                    print("entered in Room C  ")
                    print("Room C is clean")
elif current_room == 'B':

    if status == '0':
        print("your room is dirty")
        print("your room is  being clean")
        goal = input("what is your goal room")
        cost = cost + 1
        print("\n****moving towards goal*****\n")
        if goal == 'A':
            print("\n****moving left****\n")
            cost = cost + 1
            print("entered in Room A  ")
            status = input("Is this room is clean(1) or dirty(0) press (0/1)")
            if status == '0':
                print("Room A is dirty ")
                print("room A is being cleaned ")
                print("room A is cleaned ")
                cost = cost + 1
                print("\n****moving right****\n")
                cost = cost + 1
                print("Entered in room B")
                print("Room B is clean")

                print("\n****moving right****\n")
                cost = cost + 1
                print("entered in room C")
                status = input("Is this room is clean(1) or dirty(0) press (0/1)")
                if status == '0':
                    print("Room C is dirty")
                    print("Room C is being cleaned ")
                    print("Room C is cleaned ")
                    cost = cost + 1
                else:
                    print("Room C is clean")
            else:
                print("Room is clean")
                print("\n****moving right****\n")
                cost = cost + 1
                print("Entered in room B")
                print("Room B is clean")

                print("\n****moving right****\n")
                cost = cost + 1
                print("entered in room C")
                status = input("Is this room is clean(1) or dirty(0) press (0/1)")
                if status == '0':
                    print("Room C is dirty")
                    print("Room C is being cleaned ")
                    print("Room C is cleaned ")
                    cost = cost + 1
                else:
                    print("Room C is clean")

        elif goal == 'B':
            print("Room B is clean already ")



        else:
            print("\n****moving right****\n")
            cost = cost + 1
            print("entered in Room C ")
            status = input("Is this room is clean(1) or dirty(0) press (0/1)")
            if status == '0':
                print("Room C is dirty ")
                print("room C is being cleaned ")
                print("room C is cleaned ")
                cost = cost + 1
                print("\n****moving left****\n")
                cost = cost + 1
                print("Entered in room B")
                print("Room B is clean")

                print("\n****moving right****\n")
                cost = cost + 1
                print("entered in room A")
                status = input("Is this room is clean(1) or dirty(0) press (0/1)")
                if status == '0':
                    print("Room A is dirty")
                    print("Room A is being cleaned ")
                    print("Room A is cleaned ")
                    cost = cost + 1
                else:
                    print("Room A is clean")
            else:
                print("Room C is clean")
                print("\n****moving left****\n")
                cost = cost + 1
                print("Entered in room B")
                print("Room B is clean")

                print("\n****moving left****\n")
                cost = cost + 1
                print("entered in room A")
                status = input("Is this room is clean(1) or dirty(0) press (0/1)")
                if status == '0':
                    print("Room A is dirty")
                    print("Room A is being cleaned ")
                    print("Room A is cleaned ")
                    cost = cost + 1
                else:
                    print("Room A is clean")



    elif status == '1':
        print("your room is clean")
        goal = input("what is your goal room")
        print("\n****moving towards goal*****\n")
        if goal == 'A':
            print("\n****moving left****\n")
            cost = cost + 1
            print("entered in Room A  ")
            print("Room A is dirty ")
            print("room A is being cleaned ")
            print("room A is cleaned ")
            cost = cost + 1
        elif goal == 'B':
            print("Room B is clean already")

        else:
            print("\n****moving right****\n")
            cost = cost + 1
            print("entered in Room C  ")
            print("Room C is dirty")
            print("Room C is being cleaned ")
            print("Room C is cleaned ")
            cost = cost + 1

else:
    if status == '0':
        print("your room is dirty")
        print("your room is  being clean")
        cost = cost + 1
        print("\n****moving towards goal*****\n")
        goal = input("what is your goal room")
        cost = cost + 1

        if goal == 'A':
            print("\n****moving left****\n")
            print("entered in Room B  ")
            cost = cost + 1
            status = input("Is your room is clean(1) or dirty(0) press (0/1)")
            if status == '0':
                print("Room B is dirty")
                print("cleaning the room ")
                print("Room is cleaned")
                cost = cost + 1
                print("\n****moving left****\n")
                cost = cost + 1
                status = input("Is this room is clean(1) or dirty(0) press (0/1)")
                if status == '0':
                    print("entered in Room A  ")
                    print("Room A is being clean")
                    print("Room A is clean")
                    cost = cost + 1
                else:
                    print("entered in Room A  ")
                    print("Room A is clean")
            else:
                print("Room B is clean")
                print("\n****moving left****\n")
                cost = cost + 1
                status = input("Is this room is clean(1) or dirty(0) press (0/1)")
                if status == '0':
                    print("entered in Room A  ")
                    print("Room A is being clean")
                    print("Room A is clean")
                    cost = cost + 1
                else:
                    print("entered in Room A  ")
                    print("Room A is clean")

        elif goal == 'B':
            print("\n****moving left****\n")
            print("entered in Room B  ")
            cost = cost + 1
            status = input("Is your room is clean(1) or dirty(0) press (0/1)")
            if status == '0':
                print("Room B is dirty")
                print("cleaning the room ")
                print("Room is cleaned")
                cost = cost + 1
                print("\n****moving left****\n")
                cost = cost + 1
                status = input("Is this room is clean(1) or dirty(0) press (0/1)")
                if status == '0':
                    print("entered in Room A  ")
                    print("Room A is being clean")
                    print("Room A is clean")
                    cost = cost + 1
                else:
                    print("entered in Room A  ")
                    print("Room A is clean")
            else:
                print("Room B is clean")
                print("\n****moving left****\n")
                cost = cost + 1
                status = input("Is this room is clean(1) or dirty(0) press (0/1)")
                if status == '0':
                    print("entered in Room A  ")
                    print("Room A is being clean")
                    print("Room A is clean")
                    cost = cost + 1
                else:
                    print("entered in Room A  ")
                    print("Room A is clean")

    else:
        print("room C is cleaned already")


print("total cost for the cleaning is =", cost)
# Out:
# ..................................
# .   *    . ****    .  *****      .
# .  * *   . *   *   .  *          .
# . *****  . *****   .  *          .
# .*     * . *   *   .  *          .
# .        . ****    .  *****      .
# .................................
